# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
df_co2 = pd.read_excel("data/CO2.xlsx")
df_aus = pd.read_excel("data/Australia.xlsx", header=None)
df_aus = df_aus[[0,1]]
df_aus.head()
# Out:
#       0  1
# 0  1254  1
# 1  1290  2
# 2  1379  3
# 3  1346  4
# 4  1535  5

# %% [markdown]
# https://app.datacamp.com/learn/skill-tracks/time-series-with-python

# %%
plt.plot(df_co2["CO2"])

# %%
arima_model = ARIMA(df_co2["CO2"], order = (1,0,1))
model = arima_model.fit()
print(model.summary())

predict_values = model.predict(start=0, end=100)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                    CO2   No. Observations:                  161
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -219.273
# Date:                Tue, 28 May 2024   AIC                            446.546
# Time:                        20:19:21   BIC                            458.872
# Sample:                             0   HQIC                           451.551
#                                 - 161
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        339.2806      3.203    105.913      0.000     333.002     345.559
# ar.L1          0.9675      0.022     43.871      0.000       0.924       1.011
# ma.L1          0.6470      0.073      8.877      0.000       0.504       0.790
# ...

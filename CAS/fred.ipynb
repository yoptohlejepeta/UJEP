# %%
from fredapi import Fred
import plotly.express as px

key = "674fece7ba0555de6f195bbf45739006"

fred = Fred(api_key=key)
data = fred.get_series('UNRATE')

fig = px.line(data)
fig.show()

# %%
search = fred.search('unemployment')

print(search.head())
# Out:
#                   id realtime_start realtime_end  \
# series id
# UNRATE        UNRATE     2023-05-09   2023-05-09
# UNRATENSA  UNRATENSA     2023-05-09   2023-05-09
# NROU            NROU     2023-05-09   2023-05-09
# CCSA            CCSA     2023-05-09   2023-05-09
# UNEMPLOY    UNEMPLOY     2023-05-09   2023-05-09
#
#                                              title observation_start  \
# series id
# UNRATE                           Unemployment Rate        1948-01-01
# UNRATENSA                        Unemployment Rate        1948-01-01
# NROU              Noncyclical Rate of Unemployment        1949-01-01
# CCSA       Continued Claims (Insured Unemployment)        1967-01-07
# UNEMPLOY                        Unemployment Level        1948-01-01
#
#           observation_end                frequency frequency_short  \
# series id
# UNRATE         2023-04-01                  Monthly               M
# UNRATENSA      2023-04-01                  Monthly               M
# ...

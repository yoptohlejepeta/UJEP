# %%
import numpy as np
import matplotlib.pyplot as plt

intervaly = [2**n for n in range(2, 11)]

# for i in intervaly:
y1 = []
x = np.linspace(0, 4 * np.pi, 1000, retstep=True)
y = np.sin(x[0])
for j in range(1, len(x[0])-1):
    bod = x[0][j]
    xph = x[0][j-1]
    xmh = x[0][j+1]
    der = (np.sin(xph) - np.sin(xmh))/x[1]
    # print(der)
    y1.append(der)

# print(len(y1))
plt.scatter(np.linspace(0, 4 * np.pi, 998), y1)
plt.scatter(np.linspace(0, 4 * np.pi, 1000), np.cos(np.linspace(0, 4 * np.pi, 1000)))
plt.show()

# %%
x = np.linspace(0, 4 * np.pi, 1000)
y = np.cos(x)

plt.scatter(x,y)

# %%
x = np.linspace(0, 4 * np.pi, 10, retstep=True)
x[1]
# Out:
# 1.3962634015954636
